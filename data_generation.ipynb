# %%
import numpy as np 
import pandas as pd

# %%
# Source - https://stackoverflow.com/a
# Posted by joelostblom, modified by community. See post 'Timeline' for change history
# Retrieved 2026-01-28, License - CC BY-SA 4.0

iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris_csv = iris.to_csv("data/file1.csv", sep=",", index=False)
iris_tsv = iris.to_csv("data/file2.tsv", sep="\t", index=False)

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
# drop dec column 
# mean age imputation 
# mode embark_town and embarked
titanic = titanic.drop(columns=["deck"])

from sklearn.impute import SimpleImputer

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
titanic["age"] = imp_mean.fit_transform(
    titanic[["age"]]
).ravel()
imp_mode = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
titanic["embark_town"] = imp_mode.fit_transform(
    titanic[["embark_town"]]
).ravel()
titanic["embarked"] = imp_mode.fit_transform(
    titanic[["embarked"]]
).ravel()
titanic = titanic.drop(columns=["sibsp", "parch", "who", "adult_male", "embark_town", "alone"])
titanic.to_csv("data/titanic.csv", sep=",", index=False)

# %%
hnsc = pd.read_csv("data/hnsc_dataset.csv", index_col="Patient ID")
if "HPV_Status" in hnsc.columns: 
    hnsc = hnsc.drop(columns="HPV_Status")
hnsc = hnsc.reset_index()
hnsc.to_csv("data/hnsc_dataset.csv", index=False)
# Out:
# /var/folders/kb/06bb15wj1bx_tnb_wwd4mc_80000gn/T/ipykernel_17762/2335352662.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   hnsc = hnsc.reset_index()

# %%
hnsc = pd.read_csv("data/hnsc_dataset.csv", index_col="Patient ID")
hnsc
# Out:
#                   PRAME      ACTC1     MYBPC1        DES     MAGEA4  \
# Patient ID
# TCGA-4P-AA8J  10.040180  12.684538   9.001343  13.901103  12.307468
# TCGA-BA-4074   4.135157   8.137288   4.745270   9.050200   2.491751
# TCGA-BA-4076   9.590168   1.364124   0.608525   2.377901  11.791362
# TCGA-BA-4078  10.431748   3.826996   4.313435   4.954438   3.630091
# TCGA-BA-5149   1.902228   9.126284   6.089102   9.980482  12.244911
# ...                 ...        ...        ...        ...        ...
# TCGA-UF-A7JT   0.000000   7.155405   4.657777   8.286581   1.200818
# TCGA-UF-A7JV   0.000000   1.547203   0.000000   0.822934   0.000000
# TCGA-UP-A6WW   0.763072   1.032595   4.936732   2.862749   0.000000
# TCGA-WA-A7GZ   9.807406  10.842005   9.204006  12.502300   4.085994
# TCGA-WA-A7H4   2.072140  13.100902  12.032769  14.176999   8.695096
#
#                   GSTM1    UGT1A7       TGM3       CRNN     MAGEA6  ...  \
# ...
